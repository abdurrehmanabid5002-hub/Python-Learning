# %% [markdown]
# Learning Numpy

# %%
print("hello print ")
# Out:
# hello print

# %%
import numpy as np 

array = np.array([[1,2,3,4,5,6],[2,3,4,4,5,6],[1,2,3,4,5,6]])
print(array)
# Out:
# [[1 2 3 4 5 6]
#  [2 3 4 4 5 6]
#  [1 2 3 4 5 6]]
