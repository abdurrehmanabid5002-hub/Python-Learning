# %% [markdown]
# ## PSL Data Analysis

# %%
from matplotlib import pylab
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt

print(pylab.__version__)
print(np.__version__)
print(pd.__version__)
print(matplotlib.__version__)
print(matplotlib.__version__)
# Out:
# 2.5.1
# 2.5.1
# 3.0.5
# 3.11.1
# 3.11.1

# %%
df=pd.read_csv(r"C:\Users\abdur\Downloads\archive (1)\psl2026_player_stats.csv")
df
# Out:
#             player_name                team   nationality  \
# 0            Babar Azam      Peshawar Zalmi      Pakistan
# 1          Kusal Mendis      Peshawar Zalmi     Sri Lanka
# 2          Fakhar Zaman    Lahore Qalandars      Pakistan
# 3      Sahibzada Farhan      Multan Sultans      Pakistan
# 4           Steve Smith   Sialkot Stallionz     Australia
# 5           Shan Masood      Multan Sultans      Pakistan
# 6         Sameer Minhas    Islamabad United      Pakistan
# 7         Glenn Maxwell  Hyderabad Kingsmen     Australia
# 8          Mark Chapman    Islamabad United   New Zealand
# 9            Usman Khan  Hyderabad Kingsmen      Pakistan
# 10      Mohammad Rizwan              Pindiz      Pakistan
# 11         Devon Conway    Islamabad United   New Zealand
# 12         Aaron Hardie      Peshawar Zalmi     Australia
# 13       Sufiyan Muqeem      Peshawar Zalmi      Pakistan
# 14  Shaheen Shah Afridi    Lahore Qalandars      Pakistan
# ...

# %%
df.shape
# Out:
# (37, 22)

# %%
df.head()
# Out:
#         player_name               team nationality                  role  \
# 0        Babar Azam     Peshawar Zalmi    Pakistan               Batsman
# 1      Kusal Mendis     Peshawar Zalmi   Sri Lanka  Wicketkeeper-Batsman
# 2      Fakhar Zaman   Lahore Qalandars    Pakistan               Batsman
# 3  Sahibzada Farhan     Multan Sultans    Pakistan               Batsman
# 4       Steve Smith  Sialkot Stallionz   Australia               Batsman
#
#    matches  innings_bat  runs  avg_bat  strike_rate highest_score  ...  \
# 0       13           13   588    54.00       139.71          116*  ...
# 1       13           13   541    49.18       152.68           104  ...
# 2       12           12   401    38.27       143.21            87  ...
# 3       12           12   380    34.54       155.31            94  ...
# 4       11           11   380    38.00       141.26            91  ...
#
#    hundreds  fours  sixes  innings_bowl  wickets  avg_bowl  economy  \
# ...

# %%
df.tail()
# Out:
#            player_name                team  nationality         role  matches  \
# 32      Daryl Mitchell              Pindiz  New Zealand  All-rounder       11
# 33          Zaman Khan              Pindiz     Pakistan       Bowler       11
# 34  Jake Fraser-McGurk              Pindiz    Australia      Batsman       11
# 35      Mohammad Nawaz   Sialkot Stallionz     Pakistan  All-rounder       11
# 36           Saim Ayub  Hyderabad Kingsmen     Pakistan      Batsman       13
#
#     innings_bat  runs  avg_bat  strike_rate highest_score  ...  hundreds  \
# 32           11   234    23.40       138.46            62  ...         0
# 33            1     2     2.00        66.67             2  ...         0
# 34           11   242    22.00       178.67            74  ...         0
# 35            9   164    22.00       142.60            58  ...         0
# 36           13   301    27.36       150.50            88  ...         0
#
# ...

# %%
df.describe().T
# Out:
#                    count        mean         std    min     25%     50%  \
# matches             37.0   11.972973    0.865592  10.00   11.00   12.00
# innings_bat         37.0    8.621622    4.264526   1.00    4.00   11.00
# runs                37.0  215.324324  159.272836   2.00   28.00  234.00
# avg_bat             37.0   24.291081   13.658399   2.00   10.00   27.09
# strike_rate         37.0  138.775946   33.064658  66.67  128.57  142.40
# not_outs            37.0    1.351351    1.274018   0.00    0.00    1.00
# fifties             37.0    1.162162    1.093250   0.00    0.00    1.00
# hundreds            37.0    0.054054    0.229243   0.00    0.00    0.00
# fours               37.0   18.162162   15.002803   0.00    2.00   18.00
# sixes               37.0   12.702703    9.306106   0.00    1.00   14.00
# innings_bowl        37.0    6.135135    5.593459   0.00    0.00    9.00
# wickets             37.0    6.054054    6.311128   0.00    0.00    5.00
# ...

# %%
df.describe()
# Out:
#          matches  innings_bat        runs    avg_bat  strike_rate   not_outs  \
# count  37.000000    37.000000   37.000000  37.000000    37.000000  37.000000
# mean   11.972973     8.621622  215.324324  24.291081   138.775946   1.351351
# std     0.865592     4.264526  159.272836  13.658399    33.064658   1.274018
# min    10.000000     1.000000    2.000000   2.000000    66.670000   0.000000
# 25%    11.000000     4.000000   28.000000  10.000000   128.570000   0.000000
# 50%    12.000000    11.000000  234.000000  27.090000   142.400000   1.000000
# 75%    13.000000    12.000000  312.000000  33.600000   152.680000   2.000000
# max    13.000000    13.000000  588.000000  54.000000   240.000000   5.000000
#
#          fifties   hundreds      fours      sixes  innings_bowl    wickets  \
# count  37.000000  37.000000  37.000000  37.000000     37.000000  37.000000
# mean    1.162162   0.054054  18.162162  12.702703      6.135135   6.054054
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   player_name        37 non-null     str
#  1   team               37 non-null     str
#  2   nationality        37 non-null     str
#  3   role               37 non-null     str
#  4   matches            37 non-null     int64
#  5   innings_bat        37 non-null     int64
#  6   runs               37 non-null     int64
#  7   avg_bat            37 non-null     float64
#  8   strike_rate        37 non-null     float64
#  9   highest_score      37 non-null     str
#  10  not_outs           37 non-null     int64
#  11  fifties            37 non-null     int64
#  12  hundreds           37 non-null     int64
#  13  fours              37 non-null     int64
#  14  sixes              37 non-null     int64
#  15  innings_bowl       37 non-null     int64
# ...

# %%
df.columns
# Out:
# Index(['player_name', 'team', 'nationality', 'role', 'matches', 'innings_bat',
#        'runs', 'avg_bat', 'strike_rate', 'highest_score', 'not_outs',
#        'fifties', 'hundreds', 'fours', 'sixes', 'innings_bowl', 'wickets',
#        'avg_bowl', 'economy', 'best_bowling', 'four_wicket_hauls',
#        'five_wicket_hauls'],
#       dtype='str')

# %% [markdown]
# ## Clean the Data

# %%
df.isnull().sum()
# Out:
# player_name           0
# team                  0
# nationality           0
# role                  0
# matches               0
# innings_bat           0
# runs                  0
# avg_bat               0
# strike_rate           0
# highest_score         0
# not_outs              0
# fifties               0
# hundreds              0
# fours                 0
# sixes                 0
# innings_bowl          0
# wickets               0
# avg_bowl             16
# economy              16
# best_bowling         16
# four_wicket_hauls    16
# five_wicket_hauls    16
# dtype: int64

# %%
DUP=df.duplicated().sum()

print(DUP)
# Out:
# 0

# %%
run=df["runs"].cumsum().astype("Float64")

# %%
plt.plot(run)
# plt.hist(cumsum_runs,bins=[0,20,30,40,50,60,70,80,100])
plt.title("PSL Data Analysis Using NumPy")
plt.xlabel("Players ID")
plt.ylabel("Runs")
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["avg_bat"].unique()
df["avg_bat"].value_counts()
# Out:
# avg_bat
# 4.00     2
# 22.00    2
# 54.00    1
# 49.18    1
# 38.27    1
# 34.54    1
# 38.00    1
# 33.36    1
# 35.40    1
# 37.89    1
# 33.60    1
# 31.20    1
# 27.09    1
# 29.00    1
# 34.75    1
# 10.67    1
# 9.33     1
# 10.00    1
# 9.00     1
# 7.00     1
# 6.00     1
# 28.18    1
# 3.00     1
# 23.67    1
# 27.60    1
# 25.43    1
# 42.00    1
# 28.29    1
# 24.36    1
# 5.00     1
# 26.87    1
# 31.33    1
# 23.40    1
# 2.00     1
# 27.36    1
# Name: count, dtype: int64

# %%
Avgbat_graph=df["avg_bat"].cumsum().astype("Float64")
plt.plot(Avgbat_graph)
plt.title("PSL Data Analysis Using NumPy")
plt.xlabel("Players ID")
plt.ylabel("Runs")
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Strikerate_graph=df["strike_rate"].cumsum().astype("Float64")
plt.plot(Strikerate_graph)
plt.title("PSL Data Analysis Using NumPy")
plt.xlabel("Players ID")
plt.ylabel("Runs")
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Strikerate_graph=df["strike_rate"].cumsum().astype("Float64")
plt.plot(Strikerate_graph)
plt.plot(Avgbat_graph)
plt.plot(run)
plt.title("PSL Data Analysis Using NumPy")
plt.xlabel("Players ID")
plt.ylabel("Runs")
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
